# %%
import pandas as pd

# %%
experian = pd.read_csv('ExperianData.csv')
# Out:
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (3,7,11,29,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
experian.head(3)
# Out:
#                               viewer_id  h_age_coarse  h_age_fine  \
# 0  469b508d-323c-42fd-8f17-84b958ac7c82             1           2
# 1  f2cf5e6c-1a9c-4bf1-bc18-605bc9f301cd             5           9
# 2  1ccd44b0-98da-4e1c-b0b5-2e303494c8da             5          11
#
#   h_decision_maker_type  h_directorships_coarse  h_directorships_fine  \
# 0                    06                       0                     0
# 1                    02                       0                     0
# 2                    11                       0                     0
#
#   h_gas_mains_flag h_household_composition  h_household_composition_coarse  \
# 0                Y                      02                               2
# 1                N                      04                               3
# 2                Y                      08                               4
#
#    h_length_of_residency  \
# 0                      6
# 1                      4
# 2                      2
#
# ...

# %%
def logic(val):
    
    if val>= 0.8:
        res = 'Very Likely'
    elif val >= 0.6:
        res = 'Likely'
    elif val>=0.4:
        res = 'Somewhat Likely'
    elif val>=0.2:
        res = 'Unlikely'
    elif val>=0:
        res = "Very Unlikely"
    else: 
        res='NA'
    
    return res

# %%
## Create a frame with the columns
dataframe_cols = experian.columns

# %%
## Create a loop that applies the function "Logic" to the entire dataset "experian" ##

# Looks at the range of columns
for i in range(len(dataframe_cols)):
    
    # If the column starts with p_0 then create the column p_000 + i, then apply the function "logic"
    if 'p_0' in str(dataframe_cols[i]):
        experian['p_'+str(i)+'_cat'] = list(map(logic, experian[dataframe_cols[i]]))

# %%
experian.head(3)
# Out:
#                               viewer_id  h_age_coarse  h_age_fine  \
# 0  469b508d-323c-42fd-8f17-84b958ac7c82             1           2
# 1  f2cf5e6c-1a9c-4bf1-bc18-605bc9f301cd             5           9
# 2  1ccd44b0-98da-4e1c-b0b5-2e303494c8da             5          11
#
#   h_decision_maker_type  h_directorships_coarse  h_directorships_fine  \
# 0                    06                       0                     0
# 1                    02                       0                     0
# 2                    11                       0                     0
#
#   h_gas_mains_flag h_household_composition  h_household_composition_coarse  \
# 0                Y                      02                               2
# 1                N                      04                               3
# 2                Y                      08                               4
#
#    h_length_of_residency    ...     p_664_cat p_665_cat        p_666_cat  \
# ...

# %%
experian.filter(regex='_cat').head(10)
# Out:
#        p_301_cat        p_302_cat        p_303_cat      p_304_cat  \
# 0  Very Unlikely         Unlikely           Likely  Very Unlikely
# 1  Very Unlikely         Unlikely  Somewhat Likely  Very Unlikely
# 2  Very Unlikely  Somewhat Likely  Somewhat Likely  Very Unlikely
# 3  Very Unlikely           Likely         Unlikely  Very Unlikely
# 4  Very Unlikely  Somewhat Likely  Somewhat Likely  Very Unlikely
# 5  Very Unlikely    Very Unlikely           Likely  Very Unlikely
# 6  Very Unlikely         Unlikely  Somewhat Likely       Unlikely
# 7  Very Unlikely    Very Unlikely           Likely  Very Unlikely
# 8  Very Unlikely  Somewhat Likely         Unlikely  Very Unlikely
# 9       Unlikely  Somewhat Likely    Very Unlikely  Very Unlikely
#
#          p_305_cat      p_306_cat      p_307_cat      p_308_cat  \
# 0  Somewhat Likely       Unlikely  Very Unlikely  Very Unlikely
# 1    Very Unlikely  Very Unlikely  Very Unlikely  Very Unlikely
# ...

# %%
print (experian.apply(pd.value_counts))
# Out:
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:5539: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes)
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\api.py:77: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:5539: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
# ...

# %%
experian.groupby(['p_670_cat']).size().reset_index(name='p_670_cat_counts')
# Out:
#          p_670_cat  p_670_cat_counts
# 0  Somewhat Likely              9847
# 1         Unlikely               153

# %%
#experian.filter(regex='_cat').head()
