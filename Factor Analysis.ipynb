# %%
import pickle
import pandas as pd

# %%
df_hub_segmentation_test = pd.read_pickle("./hub_segmentation_df_final.pkl")
df_hub_segmentation_test.head()
# Out:
#                                       total_consumption  ACTION AND ADVENTURE  \
# viewer_id
# 000006b0-7114-4528-8ba4-708ae763ec58           1.261913                   0.0
# 0000345a-787b-4227-b591-50233c7caf7f           3.672521                   0.0
# 00006e99-ad0e-4ba4-b1f4-c45432ce1394           0.788624                   0.0
# 00007b23-89ce-451b-a034-1905c79f4f51           1.891337                   0.0
# 00008c05-80f7-4292-b6e0-2a11a4277483           1.730616                   0.0
#
#                                       ADULT ANIMATION  ARTS DOCUMENTARY  \
# viewer_id
# 000006b0-7114-4528-8ba4-708ae763ec58              0.0               0.0
# 0000345a-787b-4227-b591-50233c7caf7f              0.0               0.0
# 00006e99-ad0e-4ba4-b1f4-c45432ce1394              0.0               0.0
# 00007b23-89ce-451b-a034-1905c79f4f51              0.0               0.0
# 00008c05-80f7-4292-b6e0-2a11a4277483              0.0               0.0
#
# ...

# %%
df_hub_segmentation_reduced = df_hub_segmentation_test.drop(['total_consumption'], axis = 1)
df_hub_segmentation_reduced.head()
# Out:
#                                       ACTION AND ADVENTURE  ADULT ANIMATION  \
# viewer_id
# 000006b0-7114-4528-8ba4-708ae763ec58                   0.0              0.0
# 0000345a-787b-4227-b591-50233c7caf7f                   0.0              0.0
# 00006e99-ad0e-4ba4-b1f4-c45432ce1394                   0.0              0.0
# 00007b23-89ce-451b-a034-1905c79f4f51                   0.0              0.0
# 00008c05-80f7-4292-b6e0-2a11a4277483                   0.0              0.0
#
#                                       ARTS DOCUMENTARY  AWARD SHOWS  \
# viewer_id
# 000006b0-7114-4528-8ba4-708ae763ec58               0.0     0.000000
# 0000345a-787b-4227-b591-50233c7caf7f               0.0     0.143341
# 00006e99-ad0e-4ba4-b1f4-c45432ce1394               0.0     0.000000
# 00007b23-89ce-451b-a034-1905c79f4f51               0.0     0.000000
# 00008c05-80f7-4292-b6e0-2a11a4277483               0.0     0.000000
#
#                                       BASED ON A TRUE STORY  BIOGRAPHIES  \
# ...

# %%
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

chi_square_value, p_value = calculate_bartlett_sphericity(df_hub_segmentation_reduced)
chi_square_value, p_value
# Out:
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\linalg\linalg.py:2022: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:876: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:876: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# (nan, nan)

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all, kmo_model = calculate_kmo(df_hub_segmentation_reduced)

# %%
kmo_all, kmo_model
# Out:
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan]), nan)

# %%
fa = FactorAnalyzer()
fa.fit(df_hub_segmentation_reduced, 25)
ev, v = fa.get_eigenvalues()
ev
# Out:
# C:\Users\ryanwala\AppData\Local\Continuum\anaconda3\lib\site-packages\factor_analyzer\utils.py:48: RuntimeWarning: invalid value encountered in true_divide
#   x = (x - x.mean(0)) / x.std(0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-67d8087804a2> in <module>()
#       1 fa = FactorAnalyzer()
# ----> 2 fa.fit(df_hub_segmentation_reduced, 25)
#       3 ev, v = fa.get_eigenvalues()
#       4 ev
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\factor_analyzer\factor_analyzer.py in fit(self, X, y)
#     613             loadings = self._fit_principal(X)
#     614         else:
# --> 615             loadings = self._fit_factor_analysis(corr_mtx)
#     616
#     617         # only used if we do an oblique rotations;
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\factor_analyzer\factor_analyzer.py in _fit_factor_analysis(self, corr_mtx)
# ...

# %%
df_hub_segmentation_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6879 entries, 000006b0-7114-4528-8ba4-708ae763ec58 to 042f66dc-e7d1-48ef-a599-1856f92c0412
# Data columns (total 59 columns):
# ACTION AND ADVENTURE               6879 non-null float64
# ADULT ANIMATION                    6879 non-null float64
# ARTS DOCUMENTARY                   6879 non-null float64
# AWARD SHOWS                        6879 non-null float64
# BASED ON A TRUE STORY              6879 non-null float64
# BIOGRAPHIES                        6879 non-null float64
# BOXING                             6879 non-null float64
# CELEBRITIES SHOW                   6879 non-null float64
# CELEBRITY FACTUAL                  6879 non-null float64
# CHAT AND MAGAZINE                  6879 non-null float64
# CHAT AND MAGAZINE BIOGRAPHIES      6879 non-null float64
# CHILDREN                           6879 non-null float64
# CHILDREN FILM                      6879 non-null float64
# ...
